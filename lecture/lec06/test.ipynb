# %%
import re

text = """I will meet you at 08:30:00 pm tomorrow"""
pattern = ".*(\d\d):\d\d:\d\d.*"
matches = re.findall(pattern, text)
matches
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ZnH2\AppData\Local\Temp\ipykernel_23600\1783210371.py:4: SyntaxWarning: invalid escape sequence '\d'
#   pattern = ".*(\d\d):\d\d:\d\d.*"
# ['08']
